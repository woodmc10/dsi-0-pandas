# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
asia_df = pd.read_csv('asia.csv')

# %% [markdown]
# ## Attributes
#
# `df.shape` `df.columns`

# %%
asia_df.columns
# Out:
# Index(['Make', 'Model', 'Type', 'Origin', 'DriveTrain', 'EngineSize',
#        'Cylinders', 'Horsepower', 'MPG_City', 'MPG_Highway', 'Weight',
#        'Wheelbase', 'Length'],
#       dtype='object')

# %%
asia_df.shape
# Out:
# (158, 13)

# %% [markdown]
# ## Methods
#
# `df.head()` `df.tail()` `df.describe()` ` df.info()`

# %%
asia_df.head(2)
# Out:
#     Make           Model   Type Origin DriveTrain  EngineSize  Cylinders  \
# 0  Acura             MDX    SUV   Asia        All         3.5        6.0
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front         2.0        4.0
#
#    Horsepower  MPG_City  MPG_Highway  Weight  Wheelbase  Length
# 0         265        17           23    4451        106     189
# 1         200        24           31    2778        101     172

# %%
asia_df.tail()
# Out:
#        Make                       Model    Type Origin DriveTrain  EngineSize  \
# 153  Toyota  MR2 Spyder convertible 2dr  Sports   Asia       Rear         1.8
# 154  Toyota                      Tacoma   Truck   Asia       Rear         2.4
# 155  Toyota       Tundra Regular Cab V6   Truck   Asia       Rear         3.4
# 156  Toyota    Tundra Access Cab V6 SR5   Truck   Asia        All         3.4
# 157  Toyota                   Matrix XR   Wagon   Asia      Front         1.8
#
#      Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  Wheelbase  Length
# 153        4.0         138        26           32    2195         97     153
# 154        4.0         142        22           27    2750        103     191
# 155        6.0         190        16           18    3925        128     218
# 156        6.0         190        14           17    4435        128     218
# 157        4.0         130        29           36    2679        102     171

# %%
asia_df.describe()
# Out:
#        EngineSize   Cylinders  Horsepower    MPG_City  MPG_Highway  \
# count  158.000000  156.000000  158.000000  158.000000   158.000000
# mean     2.774051    5.185897  190.702532   22.012658    28.265823
# std      0.902310    1.269008   59.392627    6.733307     6.770503
# min      1.300000    3.000000   73.000000   13.000000    17.000000
# 25%      2.000000    4.000000  142.000000   18.000000    25.000000
# 50%      2.600000    6.000000  187.500000   20.500000    27.000000
# 75%      3.500000    6.000000  233.750000   24.000000    31.000000
# max      5.600000    8.000000  340.000000   60.000000    66.000000
#
#             Weight   Wheelbase      Length
# count   158.000000  158.000000  158.000000
# mean   3319.316456  105.886076  182.816456
# std     717.842132    7.735249   12.564148
# min    1850.000000   89.000000  153.000000
# 25%    2751.500000  102.000000  175.000000
# 50%    3280.000000  105.000000  183.500000
# 75%    3706.750000  110.000000  191.000000
# max    5590.000000  140.000000  224.000000

# %%
asia_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Make         158 non-null    object
#  1   Model        158 non-null    object
#  2   Type         158 non-null    object
#  3   Origin       158 non-null    object
#  4   DriveTrain   158 non-null    object
#  5   EngineSize   158 non-null    float64
#  6   Cylinders    156 non-null    float64
#  7   Horsepower   158 non-null    int64
#  8   MPG_City     158 non-null    int64
#  9   MPG_Highway  158 non-null    int64
#  10  Weight       158 non-null    int64
#  11  Wheelbase    158 non-null    int64
#  12  Length       158 non-null    int64
# dtypes: float64(2), int64(6), object(5)
# memory usage: 16.2+ KB

# %% [markdown]
# ## Things to notice

# %% [markdown]
# Also, there are two null values in `Cylinders`

# %% [markdown]
# ## Slicing Columns

# %%
asia_df.Make.head()
# Out:
# 0    Acura
# 1    Acura
# 2    Acura
# 3    Acura
# 4    Acura
# Name: Make, dtype: object

# %%
asia_df[['Make', 'EngineSize']].head()
# Out:
#     Make  EngineSize
# 0  Acura         3.5
# 1  Acura         2.0
# 2  Acura         2.4
# 3  Acura         3.2
# 4  Acura         3.5

# %% [markdown]
# ## Slicing Rows

# %%
asia_df[0:3]
# Out:
#     Make           Model   Type Origin DriveTrain  EngineSize  Cylinders  \
# 0  Acura             MDX    SUV   Asia        All         3.5        6.0
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front         2.0        4.0
# 2  Acura         TSX 4dr  Sedan   Asia      Front         2.4        4.0
#
#    Horsepower  MPG_City  MPG_Highway  Weight  Wheelbase  Length
# 0         265        17           23    4451        106     189
# 1         200        24           31    2778        101     172
# 2         200        22           29    3230        105     183

# %%
asia_df[10:15]
# Out:
#      Make         Model   Type Origin DriveTrain  EngineSize  Cylinders  \
# 10  Honda       CR-V LX    SUV   Asia        All         2.4        4.0
# 11  Honda    Element LX    SUV   Asia        All         2.4        4.0
# 12  Honda  Civic DX 2dr  Sedan   Asia      Front         1.7        4.0
# 13  Honda  Civic HX 2dr  Sedan   Asia      Front         1.7        4.0
# 14  Honda  Civic LX 4dr  Sedan   Asia      Front         1.7        4.0
#
#     Horsepower  MPG_City  MPG_Highway  Weight  Wheelbase  Length
# 10         160        21           25    3258        103     179
# 11         160        21           24    3468        101     167
# 12         115        32           38    2432        103     175
# 13         117        36           44    2500        103     175
# 14         115        32           38    2513        103     175

# %% [markdown]
# ## Slicing Rows and Columns

# %%
asia_df[['Make', 'EngineSize']][0:4]
# Out:
#     Make  EngineSize
# 0  Acura         3.5
# 1  Acura         2.0
# 2  Acura         2.4
# 3  Acura         3.2

# %% [markdown]
# ## .loc

# %%
asia_df.loc[0:4, ['Make', 'EngineSize']]
# Out:
#     Make  EngineSize
# 0  Acura         3.5
# 1  Acura         2.0
# 2  Acura         2.4
# 3  Acura         3.2
# 4  Acura         3.5

# %% [markdown]
# Notice this includes the 4th index!

# %% [markdown]
# ## .iloc

# %%
asia_df.iloc[0:4, [0, 7]]
# Out:
#     Make  Horsepower
# 0  Acura         265
# 1  Acura         200
# 2  Acura         200
# 3  Acura         270

# %% [markdown]
# ## Masking

# %%
asia_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Make         158 non-null    object
#  1   Model        158 non-null    object
#  2   Type         158 non-null    object
#  3   Origin       158 non-null    object
#  4   DriveTrain   158 non-null    object
#  5   EngineSize   158 non-null    float64
#  6   Cylinders    156 non-null    float64
#  7   Horsepower   158 non-null    int64
#  8   MPG_City     158 non-null    int64
#  9   MPG_Highway  158 non-null    int64
#  10  Weight       158 non-null    int64
#  11  Wheelbase    158 non-null    int64
#  12  Length       158 non-null    int64
# dtypes: float64(2), int64(6), object(5)
# memory usage: 16.2+ KB

# %%
mask = asia_df['Cylinders'].isnull()
print('.\n.\n.')
print(mask[70:80])
print('.\n.\n.')
# Out:
# .
# .
# .
# 70    False
# 71    False
# 72    False
# 73    False
# 74    False
# 75     True
# 76     True
# 77    False
# 78    False
# 79    False
# Name: Cylinders, dtype: bool
# .
# .
# .

# %%
mask = asia_df['Cylinders'].isnull()
asia_df[mask]
# Out:
#      Make               Model    Type Origin DriveTrain  EngineSize  \
# 75  Mazda  RX-8 4dr automatic  Sports   Asia       Rear         1.3
# 76  Mazda     RX-8 4dr manual  Sports   Asia       Rear         1.3
#
#     Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  Wheelbase  Length
# 75        NaN         197        18           25    3053        106     174
# 76        NaN         238        18           24    3029        106     174

# %% [markdown]
# For the nerds: Mazda RX-8 has a [rotary engine](https://en.wikipedia.org/wiki/Mazda_Wankel_engine), therefore no cylinders! Neat.

# %%
mask = asia_df['Cylinders'] > 3
asia_df[mask].head()
# Out:
#     Make           Model   Type Origin DriveTrain  EngineSize  Cylinders  \
# 0  Acura             MDX    SUV   Asia        All         3.5        6.0
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front         2.0        4.0
# 2  Acura         TSX 4dr  Sedan   Asia      Front         2.4        4.0
# 3  Acura          TL 4dr  Sedan   Asia      Front         3.2        6.0
# 4  Acura      3.5 RL 4dr  Sedan   Asia      Front         3.5        6.0
#
#    Horsepower  MPG_City  MPG_Highway  Weight  Wheelbase  Length
# 0         265        17           23    4451        106     189
# 1         200        24           31    2778        101     172
# 2         200        22           29    3230        105     183
# 3         270        20           28    3575        108     186
# 4         225        18           24    3880        115     197

# %%
mask = (asia_df['Cylinders'] > 3) & (asia_df['Horsepower'] < 200)
asia_df[mask].head()
# Out:
#      Make                                   Model    Type Origin DriveTrain  \
# 7   Honda  Civic Hybrid 4dr manual (gas/electric)  Hybrid   Asia      Front
# 10  Honda                                 CR-V LX     SUV   Asia        All
# 11  Honda                              Element LX     SUV   Asia        All
# 12  Honda                            Civic DX 2dr   Sedan   Asia      Front
# 13  Honda                            Civic HX 2dr   Sedan   Asia      Front
#
#     EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 7          1.4        4.0          93        46           51    2732
# 10         2.4        4.0         160        21           25    3258
# 11         2.4        4.0         160        21           24    3468
# 12         1.7        4.0         115        32           38    2432
# 13         1.7        4.0         117        36           44    2500
#
#     Wheelbase  Length
# 7         103     175
# 10        103     179
# 11        101     167
# 12        103     175
# 13        103     175

# %% [markdown]
# ## Sorting

# %%
asia_df.sort_values('EngineSize').head()
# Out:
#        Make                                   Model    Type Origin DriveTrain  \
# 76    Mazda                         RX-8 4dr manual  Sports   Asia       Rear
# 75    Mazda                      RX-8 4dr automatic  Sports   Asia       Rear
# 7     Honda  Civic Hybrid 4dr manual (gas/electric)  Hybrid   Asia      Front
# 141  Toyota                                Echo 4dr   Sedan   Asia      Front
# 110   Scion                                      xB   Wagon   Asia      Front
#
#      EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 76          1.3        NaN         238        18           24    3029
# 75          1.3        NaN         197        18           25    3053
# 7           1.4        4.0          93        46           51    2732
# 141         1.5        4.0         108        35           43    2055
# 110         1.5        4.0         108        31           35    2425
#
#      Wheelbase  Length
# 76         106     174
# 75         106     174
# 7          103     175
# 141         93     163
# 110         98     155

# %%
sorted_df = asia_df.sort_values('EngineSize', ascending=False)
sorted_df.head()
id(sorted_df) == id(asia_df)
# Out:
# False

# %% [markdown]
# # Create Columns

# %%
asia_df['del_me'] = 1
asia_df['del_me_2'] = 2
asia_df.head()
# Out:
#     Make           Model   Type Origin DriveTrain  EngineSize  Cylinders  \
# 0  Acura             MDX    SUV   Asia        All         3.5        6.0
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front         2.0        4.0
# 2  Acura         TSX 4dr  Sedan   Asia      Front         2.4        4.0
# 3  Acura          TL 4dr  Sedan   Asia      Front         3.2        6.0
# 4  Acura      3.5 RL 4dr  Sedan   Asia      Front         3.5        6.0
#
#    Horsepower  MPG_City  MPG_Highway  Weight  Wheelbase  Length  del_me  \
# 0         265        17           23    4451        106     189       1
# 1         200        24           31    2778        101     172       1
# 2         200        22           29    3230        105     183       1
# 3         270        20           28    3575        108     186       1
# 4         225        18           24    3880        115     197       1
#
#    del_me_2
# 0         2
# 1         2
# 2         2
# 3         2
# 4         2

# %%
asia_df['hp_to_weight'] = asia_df['Horsepower']*550/asia_df['Weight']
asia_df.head()
# Out:
#     Make           Model   Type Origin DriveTrain  EngineSize  Cylinders  \
# 0  Acura             MDX    SUV   Asia        All         3.5        6.0
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front         2.0        4.0
# 2  Acura         TSX 4dr  Sedan   Asia      Front         2.4        4.0
# 3  Acura          TL 4dr  Sedan   Asia      Front         3.2        6.0
# 4  Acura      3.5 RL 4dr  Sedan   Asia      Front         3.5        6.0
#
#    Horsepower  MPG_City  MPG_Highway  Weight  Wheelbase  Length  del_me  \
# 0         265        17           23    4451        106     189       1
# 1         200        24           31    2778        101     172       1
# 2         200        22           29    3230        105     183       1
# 3         270        20           28    3575        108     186       1
# 4         225        18           24    3880        115     197       1
#
#    del_me_2  hp_to_weight
# 0         2     32.745450
# 1         2     39.596832
# 2         2     34.055728
# 3         2     41.538462
# 4         2     31.894330

# %% [markdown]
# ## Drop Columns / Rows

# %%
asia_df.drop('del_me', axis=1, inplace=True)
del asia_df['del_me_2']

# %%
asia_df.head()
# Out:
#     Make           Model   Type Origin DriveTrain  EngineSize  Cylinders  \
# 0  Acura             MDX    SUV   Asia        All         3.5        6.0
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front         2.0        4.0
# 2  Acura         TSX 4dr  Sedan   Asia      Front         2.4        4.0
# 3  Acura          TL 4dr  Sedan   Asia      Front         3.2        6.0
# 4  Acura      3.5 RL 4dr  Sedan   Asia      Front         3.5        6.0
#
#    Horsepower  MPG_City  MPG_Highway  Weight  Wheelbase  Length  hp_to_weight
# 0         265        17           23    4451        106     189     32.745450
# 1         200        24           31    2778        101     172     39.596832
# 2         200        22           29    3230        105     183     34.055728
# 3         270        20           28    3575        108     186     41.538462
# 4         225        18           24    3880        115     197     31.894330

# %% [markdown]
# ## Unique
#
# Find your categorical features.

# %%
asia_df['Cylinders'].unique()
# Out:
# array([ 6.,  4.,  3.,  8., nan])

# %% [markdown]
# ## Value Counts

# %%
asia_df['Make'].value_counts()
# Out:
# Toyota        28
# Honda         17
# Nissan        17
# Mitsubishi    13
# Hyundai       12
# Lexus         11
# Kia           11
# Mazda         11
# Subaru        11
# Infiniti       8
# Suzuki         8
# Acura          7
# Scion          2
# Isuzu          2
# Name: Make, dtype: int64

# %% [markdown]
# ## Aggregration

# %%
asia_df.groupby('Cylinders').mean()
# Out:
#            EngineSize  Horsepower   MPG_City  MPG_Highway       Weight  \
# Cylinders
# 3.0          2.000000   73.000000  60.000000    66.000000  1850.000000
# 4.0          2.032432  145.540541  26.040541    32.310811  2784.608108
# 6.0          3.288406  222.072464  18.405797    24.884058  3702.710145
# 8.0          4.700000  294.166667  15.416667    20.250000  4581.000000
#
#             Wheelbase      Length  hp_to_weight
# Cylinders
# 3.0         95.000000  155.000000     21.702703
# 4.0        100.986486  175.486486     28.657068
# 6.0        109.739130  188.942029     33.349327
# 8.0        114.833333  196.583333     36.411333

# %% [markdown]
# #### Let's try this with a multiple columns.

# %%
asia_df.groupby(['Cylinders', 'DriveTrain']).mean()
# Out:
#                       EngineSize  Horsepower   MPG_City  MPG_Highway  \
# Cylinders DriveTrain
# 3.0       Front         2.000000   73.000000  60.000000    66.000000
# 4.0       All           2.392857  174.857143  21.071429    26.857143
#           Front         1.937037  136.574074  27.666667    34.185185
#           Rear          2.050000  157.833333  23.000000    28.166667
# 6.0       All           3.435714  221.142857  17.000000    22.071429
#           Front         3.237209  214.953488  18.953488    25.976744
#           Rear          3.300000  248.666667  18.083333    24.250000
# 8.0       All           4.816667  275.833333  14.000000    17.833333
#           Front         5.600000  305.000000  13.000000    19.000000
#           Rear          4.380000  314.000000  17.600000    23.400000
#
#                            Weight   Wheelbase      Length  hp_to_weight
# Cylinders DriveTrain
# 3.0       Front       1850.000000   95.000000  155.000000     21.702703
# 4.0       All         3240.071429  101.428571  177.285714     29.772557
#           Front       2688.629630  101.259259  175.888889     27.819612
#           Rear        2585.666667   97.500000  167.666667     33.591361
# 6.0       All         4038.000000  111.571429  190.428571     30.300196
#           Front       3652.395349  109.348837  190.116279     32.618573
#           Rear        3491.833333  109.000000  183.000000     39.525182
# 8.0       All         5097.666667  117.333333  198.500000     30.089266
#           Front       5013.000000  123.000000  207.000000     33.462996
#           Rear        3874.600000  110.200000  192.200000     44.587481

# %%
asia_df.groupby(['Cylinders', 'DriveTrain']).count()
# Out:
#                       Make  Model  Type  Origin  EngineSize  Horsepower  \
# Cylinders DriveTrain
# 3.0       Front          1      1     1       1           1           1
# 4.0       All           14     14    14      14          14          14
#           Front         54     54    54      54          54          54
#           Rear           6      6     6       6           6           6
# 6.0       All           14     14    14      14          14          14
#           Front         43     43    43      43          43          43
#           Rear          12     12    12      12          12          12
# 8.0       All            6      6     6       6           6           6
#           Front          1      1     1       1           1           1
#           Rear           5      5     5       5           5           5
#
#                       MPG_City  MPG_Highway  Weight  Wheelbase  Length  \
# Cylinders DriveTrain
# 3.0       Front              1            1       1          1       1
# 4.0       All               14           14      14         14      14
#           Front             54           54      54         54      54
#           Rear               6            6       6          6       6
# 6.0       All               14           14      14         14      14
#           Front             43           43      43         43      43
#           Rear              12           12      12         12      12
# 8.0       All                6            6       6          6       6
#           Front              1            1       1          1       1
#           Rear               5            5       5          5       5
#
#                       hp_to_weight
# Cylinders DriveTrain
# 3.0       Front                  1
# 4.0       All                   14
#           Front                 54
#           Rear                   6
# 6.0       All                   14
#           Front                 43
#           Rear                  12
# 8.0       All                    6
#           Front                  1
#           Rear                   5

# %% [markdown]
# #### Let's try this with a continuous variable... spoiler: it's way less useful.

# %%
asia_df['Horsepower'].unique()
# Out:
# array([265, 200, 270, 225, 290,  93,  73, 240, 160, 115, 117, 127, 173,
#        103, 138, 170, 194, 172, 260, 280, 255, 340, 315, 275, 193, 192,
#        104, 124, 195, 235, 230, 215, 220, 300, 130, 148, 142, 197, 238,
#        143, 207, 120, 205, 210, 271, 305, 180, 126, 175, 165, 245, 287,
#        108, 212, 227, 185, 155, 119, 110, 325, 161, 157, 190])

# %%
asia_df.groupby('Horsepower').mean()
# Out:
#             EngineSize  Cylinders   MPG_City  MPG_Highway       Weight  \
# Horsepower
# 73                 2.0   3.000000  60.000000    66.000000  1850.000000
# 93                 1.4   4.000000  46.000000    51.000000  2732.000000
# 103                1.6   4.000000  29.000000    33.000000  2294.666667
# 104                1.6   4.000000  25.666667    32.666667  2436.000000
# 108                1.5   4.000000  33.200000    39.600000  2188.000000
# ...                ...        ...        ...          ...          ...
# 300                3.7   6.666667  18.000000    23.333333  3606.000000
# 305                5.6   8.000000  13.500000    18.500000  5150.000000
# 315                4.5   8.000000  15.000000    19.000000  4309.000000
# 325                4.7   8.000000  13.000000    17.000000  5390.000000
# 340                4.5   8.000000  17.000000    23.000000  3914.000000
#
#              Wheelbase      Length  hp_to_weight
# Horsepower
# 73           95.000000  155.000000     21.702703
# 93          103.000000  175.000000     18.722548
# 103          96.000000  167.000000     24.693232
# 104          95.000000  167.000000     23.483364
# 108          94.000000  159.600000     27.292594
# ...                ...         ...           ...
# 300         104.333333  180.333333     45.983416
# 305         131.500000  215.500000     32.595882
# 315         112.000000  189.000000     40.206544
# 325         112.000000  193.000000     33.163265
# 340         111.500000  198.500000     47.789592
#
# [63 rows x 8 columns]

# %% [markdown]
# ## Combine DataFrames

# %%
other_df = pd.read_csv('america_and_europe.csv')

# %%
combined_df = pd.concat([asia_df, other_df], axis=0, sort=False)

# %%
combined_df.head()
# Out:
#     Make           Model   Type Origin DriveTrain  EngineSize  Cylinders  \
# 0  Acura             MDX    SUV   Asia        All         3.5        6.0
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front         2.0        4.0
# 2  Acura         TSX 4dr  Sedan   Asia      Front         2.4        4.0
# 3  Acura          TL 4dr  Sedan   Asia      Front         3.2        6.0
# 4  Acura      3.5 RL 4dr  Sedan   Asia      Front         3.5        6.0
#
#    Horsepower  MPG_City  MPG_Highway  Weight  Wheelbase  Length  hp_to_weight
# 0         265        17           23    4451        106     189     32.745450
# 1         200        24           31    2778        101     172     39.596832
# 2         200        22           29    3230        105     183     34.055728
# 3         270        20           28    3575        108     186     41.538462
# 4         225        18           24    3880        115     197     31.894330

# %%
price_df = pd.read_csv('price.csv')
price_df.head()
# Out:
#     Make           Model  EngineSize   MSRP  Invoice
# 0  Acura             MDX         3.5  36945    33337
# 1  Acura  RSX Type S 2dr         2.0  23820    21761
# 2  Acura         TSX 4dr         2.4  26990    24647
# 3  Acura          TL 4dr         3.2  33195    30299
# 4  Acura      3.5 RL 4dr         3.5  43755    39014

# %%
price_df.shape
# Out:
# (428, 5)

# %%
combined_price_df = combined_df.\
                    merge(price_df,
                          on=['Make', 'Model', 'EngineSize'],
                          how='left')

# %%
combined_price_df.head()
# Out:
#     Make           Model   Type Origin DriveTrain  EngineSize  Cylinders  \
# 0  Acura             MDX    SUV   Asia        All         3.5        6.0
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front         2.0        4.0
# 2  Acura         TSX 4dr  Sedan   Asia      Front         2.4        4.0
# 3  Acura          TL 4dr  Sedan   Asia      Front         3.2        6.0
# 4  Acura      3.5 RL 4dr  Sedan   Asia      Front         3.5        6.0
#
#    Horsepower  MPG_City  MPG_Highway  Weight  Wheelbase  Length  hp_to_weight  \
# 0         265        17           23    4451        106     189     32.745450
# 1         200        24           31    2778        101     172     39.596832
# 2         200        22           29    3230        105     183     34.055728
# 3         270        20           28    3575        108     186     41.538462
# 4         225        18           24    3880        115     197     31.894330
#
#     MSRP  Invoice
# 0  36945    33337
# 1  23820    21761
# 2  26990    24647
# 3  33195    30299
# 4  43755    39014

# %%
combined_price_df['MSRP'].plot(kind='hist');

# %%
combined_price_df['Horsepower'].plot(kind='hist');
